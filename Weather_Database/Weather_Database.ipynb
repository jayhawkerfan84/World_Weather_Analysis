# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial" 
query_url = f'{url}&APPID={weather_api_key}'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create an endpoint URL for each city
    city_url = query_url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]  
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather["weather"][0]["description"]    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                           "Lat" : city_lat,
                           "Lng": city_lng,
                           "Max_Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Country" : city_country,
                           "Description" : weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | vila franca do campo
# Processing Record 3 of Set 1 | itarema
# Processing Record 4 of Set 1 | high level
# Processing Record 5 of Set 1 | pierre
# Processing Record 6 of Set 1 | linxia
# Processing Record 7 of Set 1 | ilulissat
# Processing Record 8 of Set 1 | maniitsoq
# Processing Record 9 of Set 1 | nemuro
# Processing Record 10 of Set 1 | tigil
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | necochea
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | elban
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | lalmohan
# Processing Record 20 of Set 1 | saint anthony
# Processing Record 21 of Set 1 | chippewa falls
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | pampa
# Processing Record 25 of Set 1 | ballitoville
# Processing Record 26 of Set 1 | lata
# Processing Record 27 of Set 1 | emirdag
# Processing Record 28 of Set 1 | marion
# Processing Record 29 of Set 1 | the valley
# Processing Record 30 of Set 1 | vao
# Processing Record 31 of Set 1 | bundaberg
# Processing Record 32 of Set 1 | vila
# Processing Record 33 of Set 1 | mahuva
# Processing Record 34 of Set 1 | sur
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | port-gentil
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | shache
# Processing Record 43 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | chuy
# Processing Record 46 of Set 1 | miri
# Processing Record 47 of Set 1 | berdigestyakh
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | olafsvik
# Processing Record 50 of Set 1 | uralskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | ust-maya
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | turbat
# Processing Record 6 of Set 2 | vila do maio
# Processing Record 7 of Set 2 | male
# Processing Record 8 of Set 2 | silver city
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | taksimo
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | felipe carrillo puerto
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | dangtu
# Processing Record 15 of Set 2 | guerrero negro
# Processing Record 16 of Set 2 | aitape
# Processing Record 17 of Set 2 | namie
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | champerico
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | kudahuvadhoo
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | saldanha
# Processing Record 26 of Set 2 | puerto madryn
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | zhanakorgan
# Processing Record 29 of Set 2 | baiyin
# Processing Record 30 of Set 2 | ketchikan
# Processing Record 31 of Set 2 | port lincoln
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | cam ranh
# Processing Record 35 of Set 2 | portland
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 39 of Set 2 | barbastro
# Processing Record 40 of Set 2 | vaitape
# Processing Record 41 of Set 2 | lazaro cardenas
# Processing Record 42 of Set 2 | san juan del sur
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | anadyr
# Processing Record 45 of Set 2 | hay river
# Processing Record 46 of Set 2 | la ronge
# Processing Record 47 of Set 2 | sartell
# Processing Record 48 of Set 2 | klaksvik
# Processing Record 49 of Set 2 | esperance
# Processing Record 50 of Set 2 | waingapu
# Processing Record 1 of Set 3 | namibe
# Processing Record 2 of Set 3 | srednekolymsk
# Processing Record 3 of Set 3 | hofn
# Processing Record 4 of Set 3 | taoudenni
# Processing Record 5 of Set 3 | henties bay
# Processing Record 6 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 3 | kirakira
# Processing Record 8 of Set 3 | roald
# Processing Record 9 of Set 3 | caravelas
# Processing Record 10 of Set 3 | atikokan
# Processing Record 11 of Set 3 | fortuna
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | borzya
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | vila velha
# Processing Record 16 of Set 3 | tutoia
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | jawhar
# Processing Record 19 of Set 3 | saint george
# Processing Record 20 of Set 3 | letterkenny
# Processing Record 21 of Set 3 | yar-sale
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | vardo
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | kedrovyy
# Processing Record 26 of Set 3 | cassia
# Processing Record 27 of Set 3 | chokurdakh
# Processing Record 28 of Set 3 | kartuzy
# Processing Record 29 of Set 3 | nikolskoye
# Processing Record 30 of Set 3 | tuusula
# Processing Record 31 of Set 3 | pasni
# Processing Record 32 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 3 | solnechnyy
# Processing Record 34 of Set 3 | huinan
# Processing Record 35 of Set 3 | north bend
# Processing Record 36 of Set 3 | amazar
# Processing Record 37 of Set 3 | mbinga
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | berlevag
# Processing Record 40 of Set 3 | chitral
# Processing Record 41 of Set 3 | ulaangom
# Processing Record 42 of Set 3 | yenagoa
# Processing Record 43 of Set 3 | sharjah
# Processing Record 44 of Set 3 | coihaique
# Processing Record 45 of Set 3 | galesong
# Processing Record 46 of Set 3 | mwingi
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | susanville
# Processing Record 49 of Set 3 | beloha
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | mecca
# Processing Record 3 of Set 4 | beberibe
# Processing Record 4 of Set 4 | cavarzere
# Processing Record 5 of Set 4 | almaznyy
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | bam
# Processing Record 8 of Set 4 | glenwood springs
# Processing Record 9 of Set 4 | grand gaube
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | quatre cocos
# Processing Record 13 of Set 4 | tessalit
# Processing Record 14 of Set 4 | kapaa
# Processing Record 15 of Set 4 | akdagmadeni
# Processing Record 16 of Set 4 | isla vista
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | ziway
# Processing Record 19 of Set 4 | neiafu
# Processing Record 20 of Set 4 | pisco
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | carutapera
# Processing Record 23 of Set 4 | lebu
# Processing Record 24 of Set 4 | fort saint james
# Processing Record 25 of Set 4 | russell
# Processing Record 26 of Set 4 | tuatapere
# Processing Record 27 of Set 4 | luba
# Processing Record 28 of Set 4 | maracacume
# Processing Record 29 of Set 4 | tolaga bay
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | campbell river
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | soyo
# Processing Record 34 of Set 4 | port hardy
# Processing Record 35 of Set 4 | moctezuma
# Processing Record 36 of Set 4 | hobart
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | balikpapan
# Processing Record 39 of Set 4 | qingdao
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | marawi
# Processing Record 42 of Set 4 | chabahar
# Processing Record 43 of Set 4 | bilma
# Processing Record 44 of Set 4 | karratha
# Processing Record 45 of Set 4 | clyde river
# Processing Record 46 of Set 4 | nanortalik
# Processing Record 47 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | port hedland
# Processing Record 2 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 3 of Set 5 | port macquarie
# Processing Record 4 of Set 5 | houma
# Processing Record 5 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 5 | shahr-e kord
# Processing Record 7 of Set 5 | nago
# Processing Record 8 of Set 5 | chiang klang
# Processing Record 9 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 5 | ribeira grande
# Processing Record 11 of Set 5 | kalomo
# City not found. Skipping...
# Processing Record 12 of Set 5 | requena
# Processing Record 13 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | kahului
# Processing Record 17 of Set 5 | shakhta
# Processing Record 18 of Set 5 | khatanga
# Processing Record 19 of Set 5 | faanui
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 5 | qinzhou
# Processing Record 23 of Set 5 | palmer
# Processing Record 24 of Set 5 | senj
# Processing Record 25 of Set 5 | torbay
# Processing Record 26 of Set 5 | ciudad bolivar
# Processing Record 27 of Set 5 | coruripe
# Processing Record 28 of Set 5 | bakchar
# Processing Record 29 of Set 5 | pawai
# Processing Record 30 of Set 5 | turinsk
# Processing Record 31 of Set 5 | leningradskiy
# Processing Record 32 of Set 5 | vanimo
# Processing Record 33 of Set 5 | grindavik
# Processing Record 34 of Set 5 | sisimiut
# Processing Record 35 of Set 5 | san ignacio
# Processing Record 36 of Set 5 | longonjo
# Processing Record 37 of Set 5 | neyshabur
# Processing Record 38 of Set 5 | kruisfontein
# Processing Record 39 of Set 5 | cayenne
# Processing Record 40 of Set 5 | lufilufi
# Processing Record 41 of Set 5 | buala
# Processing Record 42 of Set 5 | tarauaca
# Processing Record 43 of Set 5 | manoel urbano
# Processing Record 44 of Set 5 | barra do bugres
# Processing Record 45 of Set 5 | west bay
# Processing Record 46 of Set 5 | te anau
# Processing Record 47 of Set 5 | veere
# Processing Record 48 of Set 5 | lahaina
# Processing Record 49 of Set 5 | seddon
# Processing Record 50 of Set 5 | ellensburg
# Processing Record 1 of Set 6 | baruun-urt
# Processing Record 2 of Set 6 | hithadhoo
# Processing Record 3 of Set 6 | farmington
# Processing Record 4 of Set 6 | lompoc
# Processing Record 5 of Set 6 | kodiak
# Processing Record 6 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 6 | bethel
# Processing Record 8 of Set 6 | kavieng
# Processing Record 9 of Set 6 | nouadhibou
# Processing Record 10 of Set 6 | wanning
# Processing Record 11 of Set 6 | nongstoin
# Processing Record 12 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 6 | noumea
# Processing Record 14 of Set 6 | port alfred
# Processing Record 15 of Set 6 | estelle
# Processing Record 16 of Set 6 | lasa
# Processing Record 17 of Set 6 | lisakovsk
# Processing Record 18 of Set 6 | tautira
# Processing Record 19 of Set 6 | acajutiba
# Processing Record 20 of Set 6 | altamont
# Processing Record 21 of Set 6 | fare
# Processing Record 22 of Set 6 | tikapur
# Processing Record 23 of Set 6 | saint-denis
# Processing Record 24 of Set 6 | airai
# Processing Record 25 of Set 6 | severo-kurilsk
# Processing Record 26 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 6 | riyadh
# Processing Record 29 of Set 6 | pokhara
# Processing Record 30 of Set 6 | halifax
# Processing Record 31 of Set 6 | srandakan
# Processing Record 32 of Set 6 | udachnyy
# Processing Record 33 of Set 6 | botwood
# Processing Record 34 of Set 6 | santona
# Processing Record 35 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 37 of Set 6 | tura
# Processing Record 38 of Set 6 | maceio
# Processing Record 39 of Set 6 | nioro
# Processing Record 40 of Set 6 | bull savanna
# Processing Record 41 of Set 6 | lavrentiya
# Processing Record 42 of Set 6 | longyearbyen
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | cabo san lucas
# Processing Record 45 of Set 6 | gizo
# Processing Record 46 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 47 of Set 6 | qaanaaq
# Processing Record 48 of Set 6 | ixtapa
# Processing Record 49 of Set 6 | dejen
# Processing Record 50 of Set 6 | udaipur
# Processing Record 1 of Set 7 | panama city
# Processing Record 2 of Set 7 | uribia
# Processing Record 3 of Set 7 | zhanaozen
# Processing Record 4 of Set 7 | teguldet
# Processing Record 5 of Set 7 | tasiilaq
# Processing Record 6 of Set 7 | san juan de colon
# Processing Record 7 of Set 7 | monrovia
# Processing Record 8 of Set 7 | isangel
# Processing Record 9 of Set 7 | yulara
# Processing Record 10 of Set 7 | falakata
# Processing Record 11 of Set 7 | nacala
# Processing Record 12 of Set 7 | port blair
# Processing Record 13 of Set 7 | moindou
# Processing Record 14 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 7 | sistranda
# Processing Record 16 of Set 7 | mount pleasant
# Processing Record 17 of Set 7 | ginda
# Processing Record 18 of Set 7 | college
# Processing Record 19 of Set 7 | kalmunai
# Processing Record 20 of Set 7 | lindi
# Processing Record 21 of Set 7 | kropotkin
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | nantucket
# Processing Record 25 of Set 7 | fairbanks
# Processing Record 26 of Set 7 | road town
# Processing Record 27 of Set 7 | ostersund
# Processing Record 28 of Set 7 | gedo
# Processing Record 29 of Set 7 | coquimbo
# Processing Record 30 of Set 7 | ligaya
# Processing Record 31 of Set 7 | veydelevka
# Processing Record 32 of Set 7 | krasnoslobodsk
# Processing Record 33 of Set 7 | paso del toro
# Processing Record 34 of Set 7 | aberdeen
# Processing Record 35 of Set 7 | old saybrook
# Processing Record 36 of Set 7 | lishu
# Processing Record 37 of Set 7 | mayo
# Processing Record 38 of Set 7 | chimbote
# Processing Record 39 of Set 7 | greenfield
# Processing Record 40 of Set 7 | adeje
# Processing Record 41 of Set 7 | murray bridge
# Processing Record 42 of Set 7 | iqaluit
# Processing Record 43 of Set 7 | narsaq
# Processing Record 44 of Set 7 | manzil tamim
# City not found. Skipping...
# Processing Record 45 of Set 7 | marzuq
# Processing Record 46 of Set 7 | svetlaya
# Processing Record 47 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 7 | saint-augustin
# Processing Record 50 of Set 7 | faya
# Processing Record 1 of Set 8 | lensk
# Processing Record 2 of Set 8 | husavik
# Processing Record 3 of Set 8 | aklavik
# Processing Record 4 of Set 8 | oyama
# Processing Record 5 of Set 8 | paamiut
# Processing Record 6 of Set 8 | ancud
# Processing Record 7 of Set 8 | sumenep
# Processing Record 8 of Set 8 | mbekenyera
# Processing Record 9 of Set 8 | waycross
# Processing Record 10 of Set 8 | luderitz
# Processing Record 11 of Set 8 | krasnyy
# Processing Record 12 of Set 8 | raahe
# Processing Record 13 of Set 8 | mount gambier
# Processing Record 14 of Set 8 | arlit
# Processing Record 15 of Set 8 | constitucion
# Processing Record 16 of Set 8 | bathsheba
# Processing Record 17 of Set 8 | talnakh
# Processing Record 18 of Set 8 | okhotsk
# Processing Record 19 of Set 8 | riachao das neves
# Processing Record 20 of Set 8 | brikama
# Processing Record 21 of Set 8 | makakilo city
# Processing Record 22 of Set 8 | bambous virieux
# Processing Record 23 of Set 8 | kresttsy
# Processing Record 24 of Set 8 | zhuanghe
# Processing Record 25 of Set 8 | anan
# Processing Record 26 of Set 8 | dzhebariki-khaya
# Processing Record 27 of Set 8 | tonantins
# Processing Record 28 of Set 8 | hobyo
# Processing Record 29 of Set 8 | lysyanka
# Processing Record 30 of Set 8 | mahibadhoo
# Processing Record 31 of Set 8 | caceres
# Processing Record 32 of Set 8 | shu
# Processing Record 33 of Set 8 | ewa beach
# Processing Record 34 of Set 8 | kimbe
# Processing Record 35 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 8 | koyilandi
# City not found. Skipping...
# Processing Record 37 of Set 8 | simpsonville
# Processing Record 38 of Set 8 | ust-tsilma
# Processing Record 39 of Set 8 | vostok
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | peleduy
# Processing Record 42 of Set 8 | ye
# City not found. Skipping...
# Processing Record 43 of Set 8 | nyurba
# Processing Record 44 of Set 8 | marfino
# Processing Record 45 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 8 | goderich
# Processing Record 47 of Set 8 | porto walter
# Processing Record 48 of Set 8 | kupang
# Processing Record 49 of Set 8 | upington
# Processing Record 50 of Set 8 | colac
# Processing Record 1 of Set 9 | merauke
# Processing Record 2 of Set 9 | tocopilla
# Processing Record 3 of Set 9 | pendleton
# Processing Record 4 of Set 9 | muli
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | songadh
# Processing Record 7 of Set 9 | athens
# Processing Record 8 of Set 9 | hami
# Processing Record 9 of Set 9 | kieta
# Processing Record 10 of Set 9 | boke
# Processing Record 11 of Set 9 | san-pedro
# Processing Record 12 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 9 | sechura
# Processing Record 14 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 9 | ostrovnoy
# Processing Record 16 of Set 9 | rawson
# Processing Record 17 of Set 9 | pipri
# Processing Record 18 of Set 9 | srivardhan
# Processing Record 19 of Set 9 | haridwar
# Processing Record 20 of Set 9 | kapit
# Processing Record 21 of Set 9 | kosh-agach
# Processing Record 22 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 9 | natchitoches
# Processing Record 24 of Set 9 | grand baie
# Processing Record 25 of Set 9 | dunedin
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | cap-aux-meules
# Processing Record 28 of Set 9 | tamandare
# Processing Record 29 of Set 9 | luanda
# Processing Record 30 of Set 9 | acin
# City not found. Skipping...
# Processing Record 31 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 32 of Set 9 | syracuse
# Processing Record 33 of Set 9 | tazovskiy
# Processing Record 34 of Set 9 | america dourada
# Processing Record 35 of Set 9 | malaya purga
# Processing Record 36 of Set 9 | rocha
# Processing Record 37 of Set 9 | havelock
# Processing Record 38 of Set 9 | santa cruz
# Processing Record 39 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 9 | yantal
# Processing Record 41 of Set 9 | muroto
# Processing Record 42 of Set 9 | tanout
# Processing Record 43 of Set 9 | sao joao da barra
# Processing Record 44 of Set 9 | baherden
# Processing Record 45 of Set 9 | razole
# Processing Record 46 of Set 9 | inirida
# Processing Record 47 of Set 9 | yeniseysk
# Processing Record 48 of Set 9 | guane
# Processing Record 49 of Set 9 | elat
# Processing Record 50 of Set 9 | ponnampet
# Processing Record 1 of Set 10 | killybegs
# Processing Record 2 of Set 10 | kushmurun
# Processing Record 3 of Set 10 | along
# Processing Record 4 of Set 10 | aljezur
# Processing Record 5 of Set 10 | aquidauana
# Processing Record 6 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 7 of Set 10 | douentza
# Processing Record 8 of Set 10 | arman
# Processing Record 9 of Set 10 | mahebourg
# Processing Record 10 of Set 10 | bouna
# Processing Record 11 of Set 10 | metro
# Processing Record 12 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 13 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 14 of Set 10 | ternate
# Processing Record 15 of Set 10 | launceston
# Processing Record 16 of Set 10 | soderhamn
# Processing Record 17 of Set 10 | salalah
# Processing Record 18 of Set 10 | hvide sande
# Processing Record 19 of Set 10 | beringovskiy
# Processing Record 20 of Set 10 | bowen
# Processing Record 21 of Set 10 | sfantu gheorghe
# Processing Record 22 of Set 10 | uvinza
# Processing Record 23 of Set 10 | tarboro
# Processing Record 24 of Set 10 | gejiu
# Processing Record 25 of Set 10 | maputo
# Processing Record 26 of Set 10 | dingle
# Processing Record 27 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 28 of Set 10 | bosaso
# Processing Record 29 of Set 10 | virginia beach
# Processing Record 30 of Set 10 | yaan
# Processing Record 31 of Set 10 | tanda
# Processing Record 32 of Set 10 | fukue
# Processing Record 33 of Set 10 | chotila
# Processing Record 34 of Set 10 | guaruja
# Processing Record 35 of Set 10 | dhidhdhoo
# Processing Record 36 of Set 10 | saint-joseph
# Processing Record 37 of Set 10 | coahuayana
# Processing Record 38 of Set 10 | ayan
# Processing Record 39 of Set 10 | sorong
# Processing Record 40 of Set 10 | nizhneangarsk
# Processing Record 41 of Set 10 | san miguel
# Processing Record 42 of Set 10 | salinopolis
# Processing Record 43 of Set 10 | brigantine
# Processing Record 44 of Set 10 | vallenar
# Processing Record 45 of Set 10 | cockburn town
# Processing Record 46 of Set 10 | puerto madero
# Processing Record 47 of Set 10 | ambilobe
# Processing Record 48 of Set 10 | mao
# Processing Record 49 of Set 10 | tilichiki
# Processing Record 50 of Set 10 | turkistan
# Processing Record 1 of Set 11 | burley
# Processing Record 2 of Set 11 | sovetsk
# Processing Record 3 of Set 11 | pamanukan
# Processing Record 4 of Set 11 | nyrob
# Processing Record 5 of Set 11 | hambantota
# Processing Record 6 of Set 11 | sawang daen din
# Processing Record 7 of Set 11 | videira
# Processing Record 8 of Set 11 | makarov
# Processing Record 9 of Set 11 | umm lajj
# Processing Record 10 of Set 11 | mozarlandia
# Processing Record 11 of Set 11 | adrar
# Processing Record 12 of Set 11 | baykit
# Processing Record 13 of Set 11 | salta
# Processing Record 14 of Set 11 | aswan
# Processing Record 15 of Set 11 | urengoy
# Processing Record 16 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 11 | amahai
# Processing Record 18 of Set 11 | manavalakurichi
# Processing Record 19 of Set 11 | yakeshi
# Processing Record 20 of Set 11 | brazzaville
# Processing Record 21 of Set 11 | minab
# Processing Record 22 of Set 11 | roma
# Processing Record 23 of Set 11 | tabas
# Processing Record 24 of Set 11 | moree
# Processing Record 25 of Set 11 | hervey bay
# Processing Record 26 of Set 11 | ahipara
# Processing Record 27 of Set 11 | jumla
# Processing Record 28 of Set 11 | shelburne
# Processing Record 29 of Set 11 | xiantao
# Processing Record 30 of Set 11 | coronado
# Processing Record 31 of Set 11 | gigmoto
# Processing Record 32 of Set 11 | bay roberts
# Processing Record 33 of Set 11 | aripuana
# Processing Record 34 of Set 11 | rocky mountain house
# Processing Record 35 of Set 11 | laichingen
# Processing Record 36 of Set 11 | dauphin
# Processing Record 37 of Set 11 | oranjemund
# Processing Record 38 of Set 11 | hohhot
# Processing Record 39 of Set 11 | mbala
# Processing Record 40 of Set 11 | churapcha
# Processing Record 41 of Set 11 | genhe
# Processing Record 42 of Set 11 | pangnirtung
# Processing Record 43 of Set 11 | lamar
# Processing Record 44 of Set 11 | tezu
# Processing Record 45 of Set 11 | daitari
# Processing Record 46 of Set 11 | sao jose da coroa grande
# Processing Record 47 of Set 11 | epe
# Processing Record 48 of Set 11 | zhigansk
# Processing Record 49 of Set 11 | tarko-sale
# Processing Record 50 of Set 11 | pyatigorskiy
# Processing Record 1 of Set 12 | muzhi
# Processing Record 2 of Set 12 | nome
# Processing Record 3 of Set 12 | touros
# Processing Record 4 of Set 12 | tazmalt
# Processing Record 5 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 12 | corinth
# Processing Record 7 of Set 12 | eureka
# Processing Record 8 of Set 12 | sao felix do xingu
# Processing Record 9 of Set 12 | pedernales
# Processing Record 10 of Set 12 | omboue
# Processing Record 11 of Set 12 | tabou
# Processing Record 12 of Set 12 | mana
# Processing Record 13 of Set 12 | labuhan
# Processing Record 14 of Set 12 | praia da vitoria
# Processing Record 15 of Set 12 | lehigh acres
# Processing Record 16 of Set 12 | labytnangi
# Processing Record 17 of Set 12 | kumi
# Processing Record 18 of Set 12 | saint-georges
# Processing Record 19 of Set 12 | bloemhof
# Processing Record 20 of Set 12 | bulgan
# Processing Record 21 of Set 12 | egvekinot
# Processing Record 22 of Set 12 | matara
# Processing Record 23 of Set 12 | eidsvag
# Processing Record 24 of Set 12 | mackay
# Processing Record 25 of Set 12 | ontario
# Processing Record 26 of Set 12 | los llanos de aridane
# Processing Record 27 of Set 12 | flinders
# Processing Record 28 of Set 12 | villa bruzual
# Processing Record 29 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 12 | puerto del rosario
# Processing Record 31 of Set 12 | mahon
# Processing Record 32 of Set 12 | idil
# Processing Record 33 of Set 12 | matagami
# Processing Record 34 of Set 12 | bom jesus
# Processing Record 35 of Set 12 | evensk
# Processing Record 36 of Set 12 | mercedes
# Processing Record 37 of Set 12 | nha trang
# Processing Record 38 of Set 12 | omsukchan
# Processing Record 39 of Set 12 | lazarev
# Processing Record 40 of Set 12 | neryungri
# Processing Record 41 of Set 12 | meulaboh
# Processing Record 42 of Set 12 | biysk
# Processing Record 43 of Set 12 | friendly
# Processing Record 44 of Set 12 | roblin
# Processing Record 45 of Set 12 | changji
# Processing Record 46 of Set 12 | coari
# Processing Record 47 of Set 12 | kyra
# Processing Record 48 of Set 12 | bourail
# Processing Record 49 of Set 12 | langangen
# City not found. Skipping...
# Processing Record 50 of Set 12 | quito
# Processing Record 1 of Set 13 | presidencia roque saenz pena
# Processing Record 2 of Set 13 | sinnamary
# Processing Record 3 of Set 13 | linguere
# Processing Record 4 of Set 13 | lima
# Processing Record 5 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 13 | acarau
# Processing Record 7 of Set 13 | heinola
# Processing Record 8 of Set 13 | mission bend
# Processing Record 9 of Set 13 | namalenga
# Processing Record 10 of Set 13 | korla
# Processing Record 11 of Set 13 | dunkirk
# Processing Record 12 of Set 13 | chumikan
# Processing Record 13 of Set 13 | karlsfeld
# Processing Record 14 of Set 13 | spirit river
# Processing Record 15 of Set 13 | ginir
# Processing Record 16 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 13 | melekhovskaya
# City not found. Skipping...
# Processing Record 18 of Set 13 | minas novas
# Processing Record 19 of Set 13 | longhua
# Processing Record 20 of Set 13 | samarai
# Processing Record 21 of Set 13 | khipro
# Processing Record 22 of Set 13 | lakhdenpokhya
# Processing Record 23 of Set 13 | kraskino
# Processing Record 24 of Set 13 | ponta delgada
# Processing Record 25 of Set 13 | mbandaka
# Processing Record 26 of Set 13 | davila
# Processing Record 27 of Set 13 | sisophon
# Processing Record 28 of Set 13 | montrose
# Processing Record 29 of Set 13 | mackenzie
# Processing Record 30 of Set 13 | banos
# Processing Record 31 of Set 13 | namatanai
# Processing Record 32 of Set 13 | mashhad
# Processing Record 33 of Set 13 | terrace bay
# Processing Record 34 of Set 13 | rio grande
# Processing Record 35 of Set 13 | krems
# Processing Record 36 of Set 13 | nizwa
# Processing Record 37 of Set 13 | otukpo
# Processing Record 38 of Set 13 | haines junction
# Processing Record 39 of Set 13 | southend-on-sea
# Processing Record 40 of Set 13 | kununurra
# Processing Record 41 of Set 13 | labrea
# Processing Record 42 of Set 13 | perevolotskiy
# Processing Record 43 of Set 13 | catuday
# Processing Record 44 of Set 13 | sangar
# Processing Record 45 of Set 13 | smolenka
# Processing Record 46 of Set 13 | zasosna
# Processing Record 47 of Set 13 | san vicente
# Processing Record 48 of Set 13 | pervomayskoye
# Processing Record 49 of Set 13 | nizhniy kuranakh
# Processing Record 50 of Set 13 | vestmanna
# Processing Record 1 of Set 14 | rawah
# Processing Record 2 of Set 14 | naryan-mar
# Processing Record 3 of Set 14 | ozernovskiy
# Processing Record 4 of Set 14 | peruibe
# Processing Record 5 of Set 14 | dalvik
# Processing Record 6 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 7 of Set 14 | bilibino
# Processing Record 8 of Set 14 | bryan
# Processing Record 9 of Set 14 | nunoa
# Processing Record 10 of Set 14 | jiuquan
# Processing Record 11 of Set 14 | carballo
# Processing Record 12 of Set 14 | wawa
# Processing Record 13 of Set 14 | igrim
# Processing Record 14 of Set 14 | puunsi
# City not found. Skipping...
# Processing Record 15 of Set 14 | najran
# Processing Record 16 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 14 | oskarshamn
# Processing Record 18 of Set 14 | malanje
# Processing Record 19 of Set 14 | dan khun thot
# Processing Record 20 of Set 14 | monkey bay
# Processing Record 21 of Set 14 | winnemucca
# Processing Record 22 of Set 14 | jiayuguan
# Processing Record 23 of Set 14 | waipawa
# Processing Record 24 of Set 14 | westport
# Processing Record 25 of Set 14 | san cristobal
# Processing Record 26 of Set 14 | kushima
# Processing Record 27 of Set 14 | chaozhou
# Processing Record 28 of Set 14 | alice springs
# Processing Record 29 of Set 14 | gat
# Processing Record 30 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 31 of Set 14 | karachi
# Processing Record 32 of Set 14 | nassjo
# Processing Record 33 of Set 14 | maxixe
# Processing Record 34 of Set 14 | fianarantsoa
# Processing Record 35 of Set 14 | toora-khem
# Processing Record 36 of Set 14 | romans-sur-isere
# Processing Record 37 of Set 14 | richards bay
# Processing Record 38 of Set 14 | lithakia
# Processing Record 39 of Set 14 | laguna
# Processing Record 40 of Set 14 | zemio
# Processing Record 41 of Set 14 | hornepayne
# Processing Record 42 of Set 14 | didsbury
# Processing Record 43 of Set 14 | abu zabad
# Processing Record 44 of Set 14 | stornoway
# Processing Record 45 of Set 14 | shimoda
# Processing Record 46 of Set 14 | skibbereen
# Processing Record 47 of Set 14 | conceicao da barra
# Processing Record 48 of Set 14 | pochutla
# Processing Record 49 of Set 14 | yukamenskoye
# Processing Record 50 of Set 14 | griffith
# Processing Record 1 of Set 15 | axim
# Processing Record 2 of Set 15 | verkhneuralsk
# Processing Record 3 of Set 15 | teahupoo
# Processing Record 4 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 15 | dashitou
# Processing Record 6 of Set 15 | kenosha
# Processing Record 7 of Set 15 | wageningen
# Processing Record 8 of Set 15 | cholan
# City not found. Skipping...
# Processing Record 9 of Set 15 | anloga
# Processing Record 10 of Set 15 | ust-kulom
# Processing Record 11 of Set 15 | kankon
# Processing Record 12 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 15 | kabin buri
# Processing Record 14 of Set 15 | gornyy
# Processing Record 15 of Set 15 | alta floresta
# Processing Record 16 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 15 | sampit
# Processing Record 18 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 15 | wanxian
# Processing Record 20 of Set 15 | tacuarembo
# Processing Record 21 of Set 15 | lake city
# Processing Record 22 of Set 15 | port-cartier
# Processing Record 23 of Set 15 | tonj
# Processing Record 24 of Set 15 | astoria
# Processing Record 25 of Set 15 | smithers
# Processing Record 26 of Set 15 | causapscal
# Processing Record 27 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 15 | grand-santi
# Processing Record 29 of Set 15 | voyinka
# Processing Record 30 of Set 15 | abdanan
# Processing Record 31 of Set 15 | mount isa
# Processing Record 32 of Set 15 | verkhoyansk
# Processing Record 33 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 34 of Set 15 | getashen
# Processing Record 35 of Set 15 | gaoual
# Processing Record 36 of Set 15 | kamenka
# Processing Record 37 of Set 15 | kazerun
# Processing Record 38 of Set 15 | sola
# Processing Record 39 of Set 15 | okaihau
# Processing Record 40 of Set 15 | pushchino
# Processing Record 41 of Set 15 | puerto quijarro
# Processing Record 42 of Set 15 | brainerd
# Processing Record 43 of Set 15 | marienburg
# Processing Record 44 of Set 15 | chokwe
# Processing Record 45 of Set 15 | chapais
# Processing Record 46 of Set 15 | oulainen
# Processing Record 47 of Set 15 | sorland
# Processing Record 48 of Set 15 | awjilah
# Processing Record 49 of Set 15 | kuching
# Processing Record 50 of Set 15 | acapulco
# Processing Record 1 of Set 16 | bjala
# City not found. Skipping...
# Processing Record 2 of Set 16 | tarancon
# Processing Record 3 of Set 16 | puerto leguizamo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 690

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0              Souillac -20.5167   57.5167     75.58        88          75
# 1  Vila Franca Do Campo  37.7167  -25.4333     66.61        84          77
# 2               Itarema  -2.9248  -39.9167     78.80        80           0
# 3            High Level  58.5169 -117.1360    -14.69        84          40
# 4                Pierre  44.3683 -100.3510     30.85        71           0
# 5                Linxia  35.6003  103.2064     25.12        51          98
# 6             Ilulissat  69.2167  -51.1000     19.42        73          75
# 7             Maniitsoq  65.4167  -52.9000     23.47        71          14
# 8                Nemuro  43.3236  145.5750     35.29        61          81
# 9                 Tigil  57.8000  158.6667      2.28        91          96
#
#    Wind Speed Country       Description
# 0        4.61      MU     broken clouds
# 1       25.08      PT     broken clouds
# 2       13.67      BR         clear sky
# 3        0.00      CA  scattered clouds
# 4        7.00      US         clear sky
# 5        7.25      CN   overcast clouds
# 6        0.00      GL     broken clouds
# 7        4.54      GL        few clouds
# 8        6.31      JP     broken clouds
# 9        5.01      RU   overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max_Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# DF already has this order. Switching Max_temp and cloudiness
new_order = ["City", "Country", "Lat", "Lng", "Cloudiness",  "Humidity",  "Max_Temp", "Wind Speed",  "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_order]

# Display sample data
city_data_df
# Out:
#                      City Country      Lat       Lng  Cloudiness  Humidity  \
# 0                Souillac      MU -20.5167   57.5167          75        88
# 1    Vila Franca Do Campo      PT  37.7167  -25.4333          77        84
# 2                 Itarema      BR  -2.9248  -39.9167           0        80
# 3              High Level      CA  58.5169 -117.1360          40        84
# 4                  Pierre      US  44.3683 -100.3510           0        71
# ..                    ...     ...      ...       ...         ...       ...
# 685               Awjilah      LY  29.1081   21.2869           3        31
# 686               Kuching      MY   1.5500  110.3333          20        83
# 687              Acapulco      MX  16.8634  -99.8901          20        83
# 688              Tarancon      ES  40.0085   -3.0073         100        88
# 689      Puerto Leguizamo      CO  -0.1934  -74.7819         100        73
#
#      Max_Temp  Wind Speed       Description
# 0       75.58        4.61     broken clouds
# 1       66.61       25.08     broken clouds
# 2       78.80       13.67         clear sky
# 3      -14.69        0.00  scattered clouds
# 4       30.85        7.00         clear sky
# ..        ...         ...               ...
# 685     67.03       10.47         clear sky
# 686     85.08        3.44        few clouds
# 687     78.62        2.30        few clouds
# 688     42.55       11.99        light rain
# 689     77.23        2.08   overcast clouds
#
# [690 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Cloudiness       int64
# Humidity         int64
# Max_Temp       float64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output, index_label="City_ID")
