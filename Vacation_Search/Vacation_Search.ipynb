# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geokey

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv('../Weather_Database/WeatherPy_Database.csv')

# Display sample data
city_data_df.head()
# Out:
#    City_ID                  City Country      Lat       Lng  Cloudiness  \
# 0        0              Souillac      MU -20.5167   57.5167          75
# 1        1  Vila Franca Do Campo      PT  37.7167  -25.4333          77
# 2        2               Itarema      BR  -2.9248  -39.9167           0
# 3        3            High Level      CA  58.5169 -117.1360          40
# 4        4                Pierre      US  44.3683 -100.3510           0
#
#    Humidity  Max_Temp  Wind Speed       Description
# 0        88     75.58        4.61     broken clouds
# 1        84     66.61       25.08     broken clouds
# 2        80     78.80       13.67         clear sky
# 3        84    -14.69        0.00  scattered clouds
# 4        71     30.85        7.00         clear sky

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("Enter a min temp for your trip? "))
max_temp = float(input("Enter a max temp for your trip? "))

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max_Temp"]<= max_temp) & (city_data_df["Max_Temp"]>= min_temp)]

# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID                  City Country      Lat       Lng  Cloudiness  \
# 1         1  Vila Franca Do Campo      PT  37.7167  -25.4333          77
# 11       11                Castro      BR -24.7911  -50.0119          93
# 12       12              Necochea      AR -38.5473  -58.7368          91
# 18       18              Lalmohan      BD  22.3384   90.7419           4
# 21       21               Mataura      NZ -46.1927  168.8643          70
# 24       24          Ballitoville      ZA -29.5390   31.2144         100
# 32       32                Mahuva      IN  21.0914   71.7622          21
# 33       33                   Sur      OM  22.5667   59.5289           0
# 38       38          Puerto Ayora      EC  -0.7393  -90.3518          54
# 42       42                  Chuy      UY -33.6971  -53.4616           0
#
#     Humidity  Max_Temp  Wind Speed      Description
# 1         84     66.61       25.08    broken clouds
# 11        91     67.66        1.59  overcast clouds
# 12        43     69.96        1.95  overcast clouds
# 18        64     69.31        7.14        clear sky
# 21        88     63.48        4.21    broken clouds
# 24        88     73.54        1.14       light rain
# 32        47     66.74       10.38       few clouds
# 33        67     72.93        2.59       light rain
# 38        96     69.55        3.00    broken clouds
# 42        75     66.83        8.72        clear sky

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.head()
# Out:
#     City_ID                  City Country      Lat       Lng  Cloudiness  \
# 1         1  Vila Franca Do Campo      PT  37.7167  -25.4333          77
# 11       11                Castro      BR -24.7911  -50.0119          93
# 12       12              Necochea      AR -38.5473  -58.7368          91
# 18       18              Lalmohan      BD  22.3384   90.7419           4
# 21       21               Mataura      NZ -46.1927  168.8643          70
#
#     Humidity  Max_Temp  Wind Speed      Description
# 1         84     66.61       25.08    broken clouds
# 11        91     67.66        1.59  overcast clouds
# 12        43     69.96        1.95  overcast clouds
# 18        64     69.31        7.14        clear sky
# 21        88     63.48        4.21    broken clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_travel_cities[["City","Country","Max_Temp","Description","Lat","Lng"]]
hotel_df.head(10)
# Out:
#                     City Country  Max_Temp      Description      Lat       Lng
# 1   Vila Franca Do Campo      PT     66.61    broken clouds  37.7167  -25.4333
# 11                Castro      BR     67.66  overcast clouds -24.7911  -50.0119
# 12              Necochea      AR     69.96  overcast clouds -38.5473  -58.7368
# 18              Lalmohan      BD     69.31        clear sky  22.3384   90.7419
# 21               Mataura      NZ     63.48    broken clouds -46.1927  168.8643
# 24          Ballitoville      ZA     73.54       light rain -29.5390   31.2144
# 32                Mahuva      IN     66.74       few clouds  21.0914   71.7622
# 33                   Sur      OM     72.93       light rain  22.5667   59.5289
# 38          Puerto Ayora      EC     69.55    broken clouds  -0.7393  -90.3518
# 42                  Chuy      UY     66.83        clear sky -33.6971  -53.4616

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head(10)
# Out:
#                     City Country  Max_Temp      Description      Lat  \
# 1   Vila Franca Do Campo      PT     66.61    broken clouds  37.7167
# 11                Castro      BR     67.66  overcast clouds -24.7911
# 12              Necochea      AR     69.96  overcast clouds -38.5473
# 18              Lalmohan      BD     69.31        clear sky  22.3384
# 21               Mataura      NZ     63.48    broken clouds -46.1927
# 24          Ballitoville      ZA     73.54       light rain -29.5390
# 32                Mahuva      IN     66.74       few clouds  21.0914
# 33                   Sur      OM     72.93       light rain  22.5667
# 38          Puerto Ayora      EC     69.55    broken clouds  -0.7393
# 42                  Chuy      UY     66.83        clear sky -33.6971
#
#          Lng Hotel Name
# 1   -25.4333
# 11  -50.0119
# 12  -58.7368
# 18   90.7419
# 21  168.8643
# 24   31.2144
# 32   71.7622
# 33   59.5289
# 38  -90.3518
# 42  -53.4616

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geokey,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url,params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Vila Franca Do Campo - nearest hotel: Vinha d'Areia Beach Hotel
# Castro - nearest hotel: Hotel Central Palace
# Necochea - nearest hotel: Cabañas Río Quequén
# Lalmohan - nearest hotel: No hotel found
# Mataura - nearest hotel: No hotel found
# Ballitoville - nearest hotel: The Vineyard On Ballito
# Mahuva - nearest hotel: No hotel found
# Sur - nearest hotel: Sur Hotel
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Chuy - nearest hotel: Alerces
# Turbat - nearest hotel: No hotel found
# Vila Do Maio - nearest hotel: Residencial Jardins De Maio
# Busselton - nearest hotel: No hotel found
# Felipe Carrillo Puerto - nearest hotel: Hotel María José
# Port Elizabeth - nearest hotel: Waterford Hotel
# Guerrero Negro - nearest hotel: Plaza sal paraiso
# Cape Town - nearest hotel: Townhouse Hotel
# Bredasdorp - nearest hotel: Victoria Hotel
# Saldanha - nearest hotel: Hoedjesbaai
# Puerto Madryn - nearest hotel: Hotel Gran Palace
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Port Lincoln - nearest hotel: Boston Hotel
# Bluff - nearest hotel: No hotel found
# Kaitangata - nearest hotel: No hotel found
# New Norfolk - nearest hotel: Woodbridge on the Derwent
# Esperance - nearest hotel: Best Western
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Taoudenni - nearest hotel: No hotel found
# Arraial Do Cabo - nearest hotel: No hotel found
# Vila Velha - nearest hotel: Hotel Prainha
# Jawhar - nearest hotel: Hotel Subiye
# Ponta Do Sol - nearest hotel: Estalagem Ponta do Sol
# Cassia - nearest hotel: Hotel Âncora
# Pasni - nearest hotel: No hotel found
# Mbinga - nearest hotel: No hotel found
# Hermanus - nearest hotel: Aloe guest house
# Mwingi - nearest hotel: Greenvast Hotel
# Hasaki - nearest hotel: Choshi Plaza Hotel
# Beloha - nearest hotel: No hotel found
# Mecca - nearest hotel: Rehab Al Marwa Hotel 1
# Cidreira - nearest hotel: Hotel Castelo
# Tessalit - nearest hotel: No hotel found
# Isla Vista - nearest hotel: The Club & Guest House
# Ziway - nearest hotel: Jinka Hotel
# Sao Joao Da Barra - nearest hotel: Pousada Mediterrâneo
# Inirida - nearest hotel: Residencias El Turista del Guainia
# Guane - nearest hotel: No hotel found
# Elat - nearest hotel: Melony Club
# Ponnampet - nearest hotel: Durga Boji
# Along - nearest hotel: Hotel Toshi Palace
# Aljezur - nearest hotel: Vicentina Hotel
# Douentza - nearest hotel: No hotel found
# Bouna - nearest hotel: Hôtel Éléphant  Bouna
# Launceston - nearest hotel: Hotel Charles
# Uvinza - nearest hotel: No hotel found
# Maputo - nearest hotel: No hotel found
# Bosaso - nearest hotel: Bosaso hotel
# Yaan - nearest hotel: No hotel found
# Tanda - nearest hotel: No hotel found
# Fukue - nearest hotel: 五島第一ホテル
# Chotila - nearest hotel: Hotel India
# Coahuayana - nearest hotel: No hotel found
# Vallenar - nearest hotel: Hotel del Marqués
# Ambilobe - nearest hotel: Hôtel National
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Videira - nearest hotel: Hotel Brazão
# Mozarlandia - nearest hotel: No hotel found
# Adrar - nearest hotel: No hotel found
# Salta - nearest hotel: Ayres de Salta Hotel
# Aswan - nearest hotel: Yaseen hotel
# Minab - nearest hotel: هتل صدف
# Ahipara - nearest hotel: YHA Ahipara
# Coronado - nearest hotel: Hotel Marisol Coronado
# Aripuana - nearest hotel: No hotel found
# Mbala - nearest hotel: Lake Chila Lodge
# Lamar - nearest hotel: Days Inn by Wyndham Paris
# Tezu - nearest hotel: No hotel found
# Daitari - nearest hotel: No hotel found
# Corinth - nearest hotel: Apollon
# Sao Felix Do Xingu - nearest hotel: Hotel Terraço
# Praia Da Vitoria - nearest hotel: Salles
# Lehigh Acres - nearest hotel: No hotel found
# Saint-Georges - nearest hotel: Deyna's City Inn
# Bloemhof - nearest hotel: Calimyn
# Ontario - nearest hotel: Travelodge by Wyndham Ontario
# Los Llanos De Aridane - nearest hotel: Valle Aridane
# Puerto Del Rosario - nearest hotel: Hotel Tamasite
# Mercedes - nearest hotel: Gran Hotel Mercedes
# Coari - nearest hotel: Hotel Saúde
# Presidencia Roque Saenz Pena - nearest hotel: Hotel Presidente
# Lima - nearest hotel: Hotel Peach Garden
# Mission Bend - nearest hotel: No hotel found
# Namalenga - nearest hotel: No hotel found
# Minas Novas - nearest hotel: Grande Hotel
# Longhua - nearest hotel: No hotel found
# Khipro - nearest hotel: No hotel found
# Ponta Delgada - nearest hotel: Hotel Talisman
# Mbandaka - nearest hotel: Hôtel Epervier
# Banos - nearest hotel: Hotel Sangay
# Rio Grande - nearest hotel: Hotel Vila Moura Executivo
# Nizwa - nearest hotel: Nizwa Heritage Inn
# Otukpo - nearest hotel: No hotel found
# San Vicente - nearest hotel: Los Lapachos
# Peruibe - nearest hotel: Brisamar
# Bryan - nearest hotel: The Lasalle Hotel
# Wawa - nearest hotel: No hotel found
# Najran - nearest hotel: No hotel found
# Malanje - nearest hotel: dom Fausto
# Monkey Bay - nearest hotel: Chimanga Resthouse
# Waipawa - nearest hotel: No hotel found
# San Cristobal - nearest hotel: Terra Sur
# Kushima - nearest hotel: No hotel found
# Chaozhou - nearest hotel: 潮州宾馆
# Gat - nearest hotel: No hotel found
# Karachi - nearest hotel: Quetta Agha Hotel
# Maxixe - nearest hotel: Hotel Herry
# Fianarantsoa - nearest hotel: Hôtel Mahamanina
# Richards Bay - nearest hotel: Protea Hotel
# Lithakia - nearest hotel: Κούκλα Μάρε
# Zemio - nearest hotel: No hotel found
# Abu Zabad - nearest hotel: No hotel found
# Shimoda - nearest hotel: ホテルウラガ
# Conceicao Da Barra - nearest hotel: Porto Marlin Hotel
# Pochutla - nearest hotel: Hotel El Patio
# Alta Floresta - nearest hotel: Villas Hotel
# Wanxian - nearest hotel: DoubleTree by Hilton Hotel Chongqing Wanzhou
# Tacuarembo - nearest hotel: Hotel Carlos Gardel
# Lake City - nearest hotel: Cypress Inn
# Tonj - nearest hotel: No hotel found
# Grand-Santi - nearest hotel: No hotel found
# Gaoual - nearest hotel: Hotel
# Okaihau - nearest hotel: No hotel found
# Chokwe - nearest hotel: Limpopo Hotel
# Awjilah - nearest hotel: No hotel found
#                      City Country  Max_Temp      Description      Lat  \
# 1    Vila Franca Do Campo      PT     66.61    broken clouds  37.7167
# 11                 Castro      BR     67.66  overcast clouds -24.7911
# 12               Necochea      AR     69.96  overcast clouds -38.5473
# 18               Lalmohan      BD     69.31        clear sky  22.3384
# 21                Mataura      NZ     63.48    broken clouds -46.1927
# ..                    ...     ...       ...              ...      ...
# 666           Grand-Santi      GF     71.65    broken clouds   4.2500
# 672                Gaoual      GN     72.03        clear sky  11.7500
# 676               Okaihau      NZ     66.09       light rain -35.3167
# 681                Chokwe      MZ     72.93    broken clouds -24.5333
# 685               Awjilah      LY     67.03        clear sky  29.1081
#
#           Lng                 Hotel Name
# 1    -25.4333  Vinha d'Areia Beach Hotel
# 11   -50.0119       Hotel Central Palace
# 12   -58.7368        Cabañas Río Quequén
# 18    90.7419             No hotel found
# 21   168.8643             No hotel found
# ..        ...                        ...
# 666  -54.3833             No hotel found
# 672  -13.2000                      Hotel
# 676  173.7833             No hotel found
# 681   32.9833              Limpopo Hotel
# 685   21.2869             No hotel found
#
# [205 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[hotel_df["Hotel Name"]!="No hotel found"]

# Display sample data
clean_hotel_df.head()
# Out:
#                     City Country  Max_Temp      Description      Lat      Lng  \
# 1   Vila Franca Do Campo      PT     66.61    broken clouds  37.7167 -25.4333
# 11                Castro      BR     67.66  overcast clouds -24.7911 -50.0119
# 12              Necochea      AR     69.96  overcast clouds -38.5473 -58.7368
# 24          Ballitoville      ZA     73.54       light rain -29.5390  31.2144
# 33                   Sur      OM     72.93       light rain  22.5667  59.5289
#
#                    Hotel Name
# 1   Vinha d'Areia Beach Hotel
# 11       Hotel Central Palace
# 12        Cabañas Río Quequén
# 24    The Vineyard On Ballito
# 33                  Sur Hotel

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output = ('WeatherPy_vacation.csv')

# Export the City_Data into a csv
clean_hotel_df.to_csv(output, index_label="City_ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot

hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 1000,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country", "Description"]
)

# Display the map
hotel_map
# Out:
# WARNING:param.GeoPointPlot02477: Specified size dim transform (np.sqrt(dim('Max Temp'))*1) could not be applied, as not all dimensions could be resolved.
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country,Description)
