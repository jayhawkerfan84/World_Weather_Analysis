# %%
import requests

from config import weather_api_key

from datetime import datetime

import time

from citipy import citipy

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
         citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# leningradskiy ru
# bredasdorp za
# new norfolk au
# punta arenas cl
# bredasdorp za
# atar mr
# bluff nz
# praia da vitoria pt
# poya nc
# bluff nz
# atuona pf
# bluff nz
# bontang id
# tuktoyaktuk ca
# carnarvon au
# flinders au
# port elizabeth za
# izazi tz
# cape town za
# moron mn
# busselton au
# saint-philippe re
# vaitupu wf
# dikson ru
# guerrero negro mx
# am timan td
# cockburn town bs
# svetlogorsk ru
# sobolevo ru
# airai pw
# dingle ie
# ushuaia ar
# loucovice cz
# nizhneyansk ru
# samoded ru
# illoqqortoormiut gl
# narsaq gl
# poso id
# ushuaia ar
# cayenne gf
# rikitea pf
# dologon ph
# craig us
# brae gb
# busselton au
# chuy uy
# chor pk
# mahebourg mu
# avarua ck
# tautira pf
# alice za
# vaini to
# minot us
# nizhniy kuranakh ru
# wangqing cn
# saint-pierre pm
# tiksi ru
# port macquarie au
# yunjinghong cn
# tasiilaq gl
# hobart au
# saldanha za
# sinnamary gf
# dikson ru
# airai pw
# umm bab qa
# taolanaro mg
# balotra in
# clyde river ca
# rolim de moura br
# cherskiy ru
# isangel vu
# okhotsk ru
# ancud cl
# tiksi ru
# hermanus za
# avarua ck
# east london za
# rikitea pf
# punta arenas cl
# hithadhoo mv
# tuktoyaktuk ca
# tabuk sa
# punta arenas cl
# kapaa us
# korla cn
# linhares br
# tawkar sd
# gzhatsk ru
# busselton au
# serenje zm
# moranbah au
# east london za
# eagle pass us
# osakarovka kz
# huarmey pe
# huainan cn
# illoqqortoormiut gl
# palauig ph
# rikitea pf
# busselton au
# bengkulu id
# ambon id
# barentsburg sj
# balimo pg
# mys shmidta ru
# uk ru
# sao filipe cv
# port blair in
# airai pw
# torbay ca
# northam au
# saint-leu re
# vaini to
# tuktoyaktuk ca
# cabo san lucas mx
# san jeronimo mx
# samusu ws
# demba cd
# saint-philippe re
# hamilton bm
# padang id
# belushya guba ru
# cidreira br
# vredendal za
# saint-philippe re
# rikitea pf
# mataura pf
# punta arenas cl
# port hedland au
# vaini to
# serik tr
# cape town za
# jamestown sh
# lyngseidet no
# attawapiskat ca
# hilo us
# punta arenas cl
# washington us
# castro cl
# hermanus za
# attawapiskat ca
# komsomolskiy ru
# vaini to
# kavieng pg
# acarau br
# flinders au
# chuy uy
# maumere id
# bereznik ru
# rikitea pf
# punta arenas cl
# tilichiki ru
# grand river south east mu
# labuhan id
# leningradskiy ru
# saint-philippe re
# butaritari ki
# cape town za
# mahebourg mu
# barrow us
# nizhneyansk ru
# saint george bm
# ushuaia ar
# asosa et
# san cristobal ec
# yellowknife ca
# kavieng pg
# cherskiy ru
# nome us
# lugo es
# biak id
# bilibino ru
# olafsvik is
# trairi br
# piro in
# beaune fr
# rungata ki
# bathsheba bb
# bluff nz
# pitea se
# ushuaia ar
# trinidad cu
# sarh td
# tuktoyaktuk ca
# jishu cn
# georgetown sh
# tidore id
# hermanus za
# nikolskoye ru
# kirishi ru
# kutum sd
# busselton au
# borama so
# new norfolk au
# diu in
# lastoursville ga
# vaini to
# saskylakh ru
# luanda ao
# busselton au
# barrow us
# puerto ayora ec
# vitoria da conquista br
# pisco pe
# avarua ck
# mys shmidta ru
# hilo us
# georgetown sh
# rincon de la victoria es
# jamestown sh
# lolua tv
# rikitea pf
# new norfolk au
# uglerodovskiy ru
# cabo san lucas mx
# punta arenas cl
# shestakovo ru
# cidreira br
# paranapanema br
# newport us
# mataura pf
# avarua ck
# hobart au
# aksarka ru
# dikson ru
# sungaipenuh id
# rikitea pf
# souillac mu
# tiksi ru
# tuktoyaktuk ca
# busselton au
# mataura pf
# ushuaia ar
# albany au
# ushuaia ar
# vaini to
# ipixuna br
# evensk ru
# faya td
# hami cn
# grindavik is
# saskylakh ru
# new norfolk au
# hithadhoo mv
# stokmarknes no
# grand river south east mu
# dikson ru
# hobyo so
# kruisfontein za
# mar del plata ar
# praia da vitoria pt
# marcona pe
# ballina ie
# east london za
# kabare cd
# taolanaro mg
# afua br
# lagoa pt
# leningradskiy ru
# new norfolk au
# bethel us
# conceicao do araguaia br
# punta arenas cl
# grand gaube mu
# bethel us
# bredasdorp za
# codrington ag
# yeppoon au
# vila vu
# punta arenas cl
# cape town za
# jamestown sh
# mataura pf
# chuy uy
# bethel us
# barentsburg sj
# new norfolk au
# mataura pf
# scarborough tt
# belushya guba ru
# bluff nz
# lebu cl
# skibbereen ie
# yellowknife ca
# port alfred za
# qaanaaq gl
# hobart au
# taolanaro mg
# salinopolis br
# palabuhanratu id
# chara ru
# dingle ie
# hermanus za
# carutapera br
# tiksi ru
# busselton au
# guarapuava br
# bredasdorp za
# east london za
# hithadhoo mv
# albany au
# belushya guba ru
# hofn is
# mahajanga mg
# griffin us
# aanekoski fi
# saint-philippe re
# vanavara ru
# port macquarie au
# saint-philippe re
# butaritari ki
# ambodifototra mg
# rikitea pf
# dauriya ru
# rikitea pf
# alta no
# ushuaia ar
# sinnamary gf
# ushuaia ar
# atuona pf
# salalah om
# kupang id
# troitsk ru
# jamestown sh
# belaya gora ru
# jomalig ph
# isangel vu
# meulaboh id
# avarua ck
# mataura pf
# ponta delgada pt
# attawapiskat ca
# longyearbyen sj
# thompson ca
# rikitea pf
# amreli in
# kaitangata nz
# grand-lahou ci
# lompoc us
# longyearbyen sj
# busselton au
# cape town za
# butaritari ki
# dikson ru
# ilulissat gl
# auki sb
# peniche pt
# buena vista bo
# skibotn no
# victoria sc
# komsomolskiy ru
# cape town za
# rikitea pf
# murgab tm
# mareeba au
# conceicao do araguaia br
# yellowknife ca
# saint-philippe re
# victoria sc
# cabedelo br
# san felipe ve
# puerto ayora ec
# barrow us
# ponta do sol cv
# waipawa nz
# qaqortoq gl
# tiksi ru
# kapaa us
# mount gambier au
# lorengau pg
# castro cl
# port blair in
# atuona pf
# atuona pf
# alta floresta br
# adrar dz
# castro cl
# vaini to
# bluff nz
# new norfolk au
# faanui pf
# broken hill au
# dingle ie
# belushya guba ru
# hermanus za
# takoradi gh
# chokurdakh ru
# avarua ck
# uwayl sd
# albany au
# bryan us
# severo-kurilsk ru
# tuktoyaktuk ca
# hithadhoo mv
# bogovarovo ru
# katsuura jp
# san quintin mx
# tuatapere nz
# rikitea pf
# hermanus za
# sentyabrskiy ru
# cayenne gf
# shingu jp
# banikoara bj
# barentsburg sj
# almaznyy ru
# nome us
# ushuaia ar
# busselton au
# sherbrooke ca
# taolanaro mg
# teya ru
# albany au
# dire ml
# atuona pf
# ushuaia ar
# kikwit cd
# taolanaro mg
# semporna my
# bengkulu id
# mar del plata ar
# san alejo sv
# hobart au
# barrow us
# marcona pe
# kapaa us
# sitka us
# norman wells ca
# amderma ru
# atambua id
# illoqqortoormiut gl
# inongo cd
# tuktoyaktuk ca
# tiksi ru
# tasiilaq gl
# port elizabeth za
# ulundi za
# san patricio mx
# taolanaro mg
# bethel us
# attawapiskat ca
# mar del plata ar
# ponta delgada pt
# east london za
# san cristobal ec
# nikolskoye ru
# illoqqortoormiut gl
# north myrtle beach us
# thompson ca
# rio gallegos ar
# ushuaia ar
# bluff nz
# arraial do cabo br
# hermanus za
# dikson ru
# busselton au
# garmsar ir
# hithadhoo mv
# barrow us
# punta arenas cl
# nome us
# sentyabrskiy ru
# ushuaia ar
# vaini to
# birao cf
# chuy uy
# shu kz
# kaitangata nz
# puerto madero mx
# taolanaro mg
# esperance au
# kidal ml
# pevek ru
# dusti tj
# honiara sb
# evensk ru
# yulara au
# viedma ar
# albany au
# le port re
# comodoro rivadavia ar
# barrow us
# santa isabel do rio negro br
# jamestown sh
# puerto ayora ec
# bluff nz
# puerto suarez bo
# dingle ie
# jamestown sh
# suchitlan mx
# krasnoselkup ru
# gilgit pk
# taolanaro mg
# punta arenas cl
# atchison us
# puerto carreno co
# ushuaia ar
# sakakah sa
# kaitangata nz
# tuktoyaktuk ca
# am timan td
# port elizabeth za
# mataura pf
# evensk ru
# shingu jp
# mocuba mz
# portland au
# belushya guba ru
# kavieng pg
# mahenge tz
# mongu zm
# mataura pf
# vaini to
# albany au
# vila velha br
# airai pw
# kapaa us
# arraial do cabo br
# kapaa us
# mys shmidta ru
# albany au
# punta arenas cl
# lebu cl
# karaul ru
# qaqortoq gl
# rikitea pf
# saint george bm
# souillac mu
# bredasdorp za
# hobart au
# bengkulu id
# avarua ck
# vaitupu wf
# punta arenas cl
# hilo us
# hilo us
# ribeira grande pt
# butaritari ki
# sentyabrskiy ru
# ushuaia ar
# punta arenas cl
# ushuaia ar
# barentsburg sj
# ratnagiri in
# ocos gt
# flagstaff us
# totoral bo
# atbasar kz
# manokwari id
# ushuaia ar
# taolanaro mg
# ushuaia ar
# cape town za
# tuktoyaktuk ca
# geraldton au
# new norfolk au
# ostrovnoy ru
# labuhan id
# jizan sa
# new norfolk au
# vaitupu wf
# aklavik ca
# brae gb
# cape town za
# port alfred za
# hilo us
# georgetown sh
# cape town za
# cherskiy ru
# chicama pe
# jamestown sh
# airai pw
# ushuaia ar
# upernavik gl
# sakakah sa
# belushya guba ru
# puerto ayora ec
# antalaha mg
# khatanga ru
# ushuaia ar
# carnarvon au
# vaini to
# upernavik gl
# leningradskiy ru
# namatanai pg
# griffith au
# hermanus za
# ushuaia ar
# grindavik is
# vaini to
# kapaa us
# saint-philippe re
# bud no
# elat il
# pleszew pl
# saskylakh ru
# hilo us
# bluff nz
# castro cl
# punta arenas cl
# longyearbyen sj
# castro cl
# thompson ca
# mar del plata ar
# hambantota lk
# vostok ru
# killybegs ie
# rikitea pf
# qaanaaq gl
# fortuna us
# cherskiy ru
# mataura pf
# kamenskoye ru
# busselton au
# hobyo so
# blonduos is
# atuona pf
# mount gambier au
# kahului us
# los llanos de aridane es
# saldanha za
# mataura pf
# ketchikan us
# mataura pf
# nikolayevsk-na-amure ru
# tiksi ru
# cabo san lucas mx
# vaitupu wf
# busselton au
# ushuaia ar
# mataura pf
# mataura pf
# ouallam ne
# barra do garcas br
# arraial do cabo br
# tiksi ru
# nome us
# mataura pf
# grootfontein na
# ushuaia ar
# bawku gh
# rikitea pf
# albany au
# rikitea pf
# kapaa us
# kangalassy ru
# sabang id
# ribeira grande pt
# busselton au
# taganak ph
# samusu ws
# narsaq gl
# puerto ayora ec
# apastovo ru
# east london za
# katsuura jp
# kapaa us
# pangody ru
# atuona pf
# plettenberg bay za
# kamaishi jp
# cape town za
# chuy uy
# nanortalik gl
# keflavik is
# clyde river ca
# avarua ck
# albany au
# cabo san lucas mx
# lebu cl
# deputatskiy ru
# rikitea pf
# cayenne gf
# dzilam gonzalez mx
# mataura pf
# carutapera br
# castro cl
# kapaa us
# cape town za
# namibe ao
# carnarvon au
# diebougou bf
# taolanaro mg
# portland au
# atuona pf
# port lincoln au
# port alfred za
# umm lajj sa
# ushuaia ar
# ponta do sol pt
# rikitea pf
# saskylakh ru
# nikolskoye ru
# east london za
# qaanaaq gl
# illoqqortoormiut gl
# baruun-urt mn
# provideniya ru
# ituni gy
# butaritari ki
# saint anthony ca
# ushuaia ar
# mataura pf
# cidreira br
# butaritari ki
# naumburg de
# souillac mu
# matara lk
# jamestown sh
# altay cn
# mataura pf
# attawapiskat ca
# maku ir
# pangody ru
# cape town za
# rungata ki
# busselton au
# saskylakh ru
# beringovskiy ru
# bambanglipuro id
# okha ru
# kruisfontein za
# port elizabeth za
# yulara au
# ternate id
# kifri iq
# ushuaia ar
# taolanaro mg
# lagoa pt
# dikson ru
# ushuaia ar
# albany au
# chokurdakh ru
# punta arenas cl
# portland au
# busselton au
# ushuaia ar
# lavrentiya ru
# albany au
# port elizabeth za
# viligili mv
# vanavara ru
# tecoanapa mx
# rosarito mx
# santiago de cao pe
# atuona pf
# gilgit pk
# arraial do cabo br
# yirol sd
# chuy uy
# kavieng pg
# nikolskoye ru
# busselton au
# sentyabrskiy ru
# constitucion mx
# bredasdorp za
# punta arenas cl
# rikitea pf
# rikitea pf
# mahebourg mu
# ushuaia ar
# new norfolk au
# albany au
# atuona pf
# bambous virieux mu
# minot us
# vaini to
# mataura pf
# ambon id
# alyangula au
# waingapu id
# podgorica me
# punta arenas cl
# chokurdakh ru
# mys shmidta ru
# aginskoye ru
# padang id
# kapaa us
# mataura pf
# felipe carrillo puerto mx
# ushuaia ar
# east london za
# sao filipe cv
# atuona pf
# butaritari ki
# esperance au
# kawalu id
# korla cn
# ilebo cd
# qaanaaq gl
# punta arenas cl
# saskylakh ru
# amderma ru
# mahebourg mu
# falealupo ws
# kawalu id
# chicama pe
# tambul sd
# east london za
# hambantota lk
# east london za
# khuzhir ru
# nikolskoye ru
# esperance au
# busselton au
# rio gallegos ar
# saint george bm
# kodiak us
# sawankhalok th
# hobart au
# rancho palos verdes us
# ushuaia ar
# rikitea pf
# kenai us
# borujerd ir
# avarua ck
# albany au
# vao nc
# tezu in
# ugoofaaru mv
# barrow us
# hobart au
# tadine nc
# avarua ck
# cape town za
# puerto ayora ec
# san jeronimo de tunan pe
# portland au
# pavilosta lv
# ketchikan us
# hilo us
# bouna ci
# zhaotong cn
# chuy uy
# bredasdorp za
# sinnamary gf
# shenjiamen cn
# rikitea pf
# hobart au
# kunnamkulam in
# saint-philippe re
# busselton au
# olafsvik is
# padang id
# souillac mu
# nikolskoye ru
# tiksi ru
# grand gaube mu
# kapaa us
# dakar sn
# khonuu ru
# lebu cl
# hofn is
# victoria sc
# sorland no
# camopi gf
# mao td
# coleraine gb
# mataura pf
# flinders au
# airai pw
# puerto ayora ec
# isangel vu
# new norfolk au
# jalu ly
# port alfred za
# lerwick gb
# berlevag no
# cap-chat ca
# college us
# tianpeng cn
# sistranda no
# tuatapere nz
# port elizabeth za
# afmadu so
# bridlington gb
# albany au
# vaini to
# roald no
# kununurra au
# ushuaia ar
# avarua ck
# pimenta bueno br
# hobart au
# prince rupert ca
# komsomolskiy ru
# blonduos is
# khatanga ru
# impfondo cg
# puerto colombia co
# zhigansk ru
# barentsburg sj
# chokurdakh ru
# new norfolk au
# sinkat sd
# upernavik gl
# ushuaia ar
# vaini to
# naze jp
# bluff nz
# talavera pe
# nguiu au
# ancud cl
# jamestown sh
# kapaa us
# viedma ar
# saint-ambroise ca
# hofn is
# portland au
# hobart au
# albany au
# vaini to
# constantine dz
# montague ca
# qaanaaq gl
# vaitupu wf
# galeana mx
# carnarvon au
# chimoio mz
# ribeira grande pt
# tura ru
# ushuaia ar
# carnarvon au
# rikitea pf
# chokurdakh ru
# weligama lk
# thompson ca
# ancud cl
# aswan eg
# homer us
# ketchikan us
# gotsu jp
# new norfolk au
# atuona pf
# port augusta au
# bairiki ki
# leningradskiy ru
# auchterarder gb
# dimitrovgrad rs
# ostrovnoy ru
# bluff nz
# quzhou cn
# saint-pierre pm
# busselton au
# saint-augustin ca
# coquimbo cl
# ribeira grande pt
# busselton au
# yerbogachen ru
# sault sainte marie ca
# atuona pf
# sibut cf
# hilo us
# vaitupu wf
# vesyegonsk ru
# samarai pg
# illoqqortoormiut gl
# ushuaia ar
# nikolskoye ru
# yulara au
# atuona pf
# meulaboh id
# bambous virieux mu
# new norfolk au
# isangel vu
# auki sb
# fasa ir
# tateyama jp
# ushuaia ar
# beringovskiy ru
# zhob pk
# mar del plata ar
# saskylakh ru
# belushya guba ru
# ushuaia ar
# nikolskoye ru
# lompoc us
# busselton au
# ambon id
# brae gb
# nanortalik gl
# anakapalle in
# port alfred za
# vardo no
# bluff nz
# ushuaia ar
# bubaque gw
# aquiraz br
# quimper fr
# beira mz
# hilo us
# zhigansk ru
# chamba in
# tautira pf
# pansemal in
# cape town za
# bluff nz
# kapaa us
# vuktyl ru
# nanortalik gl
# busselton au
# brae gb
# blackwater au
# mataura pf
# hilo us
# ushuaia ar
# rikitea pf
# cap malheureux mu
# nepalganj np
# rio grande br
# severo-kurilsk ru
# rikitea pf
# urazovka ru
# hobart au
# yanai jp
# ushuaia ar
# khatanga ru
# mataura pf
# ancud cl
# hithadhoo mv
# sungaipenuh id
# quelimane mz
# port alfred za
# port blair in
# yarada in
# illoqqortoormiut gl
# atuona pf
# ushuaia ar
# longyearbyen sj
# touros br
# high level ca
# cape town za
# sao filipe cv
# kapaa us
# mahebourg mu
# qaanaaq gl
# sinnamary gf
# varnavino ru
# voh nc
# dourbali td
# hilo us
# bradley us
# skjervoy no
# esperance au
# victoria sc
# chagda ru
# hualmay pe
# los llanos de aridane es
# porto novo cv
# manaus br
# nizhneyansk ru
# roebourne au
# rawannawi ki
# punta arenas cl
# vaini to
# busselton au
# chuy uy
# yeppoon au
# port elizabeth za
# cape town za
# hobart au
# muli mv
# coihaique cl
# cidreira br
# progreso mx
# lethem gy
# bredasdorp za
# rikitea pf
# mataura pf
# ushuaia ar
# kampene cd
# takoradi gh
# ushuaia ar
# akyab mm
# alofi nu
# vaini to
# catuday ph
# ullapool gb
# rikitea pf
# belushya guba ru
# avarua ck
# vaini to
# avarua ck
# bluff nz
# tocopilla cl
# cidreira br
# andenes no
# kapaa us
# codrington ag
# taolanaro mg
# kaitangata nz
# busselton au
# vostok ru
# nakhodka ru
# liku wf
# mataura pf
# rehoboth na
# krasnoselkup ru
# gat ly
# yellowknife ca
# belushya guba ru
# atuona pf
# rikitea pf
# punta arenas cl
# tuatapere nz
# albany au
# conceicao da barra br
# bayonet point us
# mahebourg mu
# barrow us
# yellowknife ca
# lata sb
# banjar id
# roma au
# waipawa nz
# rikitea pf
# jubayl lb
# lasa cn
# hilo us
# kontagora ng
# tuktoyaktuk ca
# tuatapere nz
# krasnousolskiy ru
# kapaa us
# albany au
# ushuaia ar
# khatanga ru
# bonavista ca
# cape town za
# melfi td
# rikitea pf
# port alfred za
# punta arenas cl
# alofi nu
# hobart au
# hobart au
# port elizabeth za
# russell nz
# leningradskiy ru
# punta arenas cl
# hasaki jp
# menongue ao
# anadyr ru
# kodiak us
# mataura pf
# todos santos mx
# ushuaia ar
# kukuna sl
# new norfolk au
# elena bg
# severnyy ru
# jamestown sh
# shorewood us
# ushuaia ar
# emerald au
# hermanus za
# dondo mz
# bafq ir
# chokurdakh ru
# tiruvottiyur in
# caucaia br
# punta arenas cl
# jamestown sh
# qaanaaq gl
# karamea nz
# vila franca do campo pt
# amambai br
# emirdag tr
# saint george bm
# sitka us
# rikitea pf
# pangai to
# airai pw
# knysna za
# tuatapere nz
# taolanaro mg
# avarua ck
# kasongo cd
# bluff nz
# rikitea pf
# merauke id
# xghajra mt
# taolanaro mg
# manokwari id
# rikitea pf
# mareeba au
# hermanus za
# bathsheba bb
# swift current ca
# hobart au
# victoria sc
# punta arenas cl
# lima pe
# saskylakh ru
# port alfred za
# bichura ru
# barentsburg sj
# tiarei pf
# bluff nz
# san quintin mx
# bluff nz
# rikitea pf
# dzhebariki-khaya ru
# busselton au
# ballina ie
# waw sd
# hermanus za
# lavrentiya ru
# kutum sd
# sharlyk ru
# henties bay na
# georgetown sh
# mys shmidta ru
# nikel ru
# kemin kg
# manvi in
# longyearbyen sj
# bredasdorp za
# kuche cn
# kurumkan ru
# vaitupu wf
# punta arenas cl
# marrakesh ma
# mataura pf
# salvador br
# te anau nz
# cabedelo br
# esil kz
# illoqqortoormiut gl
# patamundai in
# kapaa us
# bluff nz
# severo-kurilsk ru
# upernavik gl
# obuasi gh
# kodiak us
# amderma ru
# semey kz
# kokstad za
# rikitea pf
# mahebourg mu
# chuy uy
# puerto suarez bo
# puerto ayora ec
# luderitz na
# along in
# albany au
# carauari br
# yelizovo ru
# geraldton au
# carira br
# itarema br
# new norfolk au
# hasaki jp
# illoqqortoormiut gl
# camara de lobos pt
# atikokan ca
# cape town za
# pevek ru
# mys shmidta ru
# acapulco mx
# victoria sc
# hasaki jp
# bluff nz
# oktyabrskiy ru
# uige ao
# busselton au
# chokurdakh ru
# laguna br
# jamestown sh
# nelson bay au
# albany au
# la palma pa
# port alfred za
# aklavik ca
# okato nz
# bredasdorp za
# butaritari ki
# adrar dz
# santa luzia br
# ushuaia ar
# lisakovsk kz
# rikitea pf
# muros es
# bluff nz
# mar del plata ar
# hammerfest no
# arlit ne
# new norfolk au
# taolanaro mg
# bethel us
# soubre ci
# yining cn
# grindavik is
# ushuaia ar
# cape town za
# punta arenas cl
# manokwari id
# hermanus za
# new norfolk au
# chokurdakh ru
# illoqqortoormiut gl
# hosakote in
# codrington ag
# oranjestad aw
# amderma ru
# shingu jp
# ugoofaaru mv
# arraial do cabo br
# mataura pf
# albany au
# bluff nz
# zheshart ru
# laguna br
# albany au
# kapaa us
# bathsheba bb
# popondetta pg
# saint george bm
# castro cl
# moroni km
# ribeira grande pt
# puerto ayora ec
# palmer us
# vaitupu wf
# taolanaro mg
# avarua ck
# belushya guba ru
# salalah om
# lima pe
# belomorsk ru
# saleaula ws
# satitoa ws
# attawapiskat ca
# ushuaia ar
# kununurra au
# tuktoyaktuk ca
# nome us
# souillac mu
# galesong id
# goderich sl
# saint-philippe re
# lompoc us
# ancud cl
# butaritari ki
# northam au
# kapaa us
# faanui pf
# egvekinot ru
# rikitea pf
# busselton au
# kapaa us
# belushya guba ru
# butaritari ki
# ponta do sol cv
# ushuaia ar
# hay river ca
# arica cl
# attawapiskat ca
# busselton au
# vaitupu wf
# butaritari ki
# murree pk
# vao nc
# saint-francois gp
# ushuaia ar
# rio gallegos ar
# komsomolskiy ru
# saint george bm
# barrow us
# east london za
# kaeo nz
# yulara au
# komsomolskiy ru
# new norfolk au
# lolua tv
# punta arenas cl
# illoqqortoormiut gl
# hithadhoo mv
# xichang cn
# port-gentil ga
# avarua ck
# kupang id
# havre-saint-pierre ca
# rikitea pf
# mayumba ga
# ilulissat gl
# longkou cn
# amderma ru
# qaanaaq gl
# brookhaven us
# cabo san lucas mx
# rikitea pf
# centerville us
# spornoye ru
# lephepe bw
# olanchito hn
# puerto ayora ec
# sola vu
# hobart au
# attawapiskat ca
# arraial do cabo br
# la primavera co
# beringovskiy ru
# narsaq gl
# atuona pf
# sitrah bh
# atuona pf
# hilo us
# saldanha za
# taolanaro mg
# comodoro rivadavia ar
# yellowknife ca
# saskylakh ru
# khor qa
# kahului us
# rikitea pf
# ust-nera ru
# vaini to
# marcona pe
# torbay ca
# guerrero negro mx
# sao joao da barra br
# ribeira grande pt
# hay river ca
# belushya guba ru
# zdvinsk ru
# mackay au
# bredasdorp za
# cape town za
# koksovyy ru
# zhuhai cn
# castro cl
# hirara jp
# pombas cv
# busselton au
# albany au
# jiaozhou cn
# amderma ru
# rikitea pf
# luderitz na
# kavaratti in
# mataura pf
# punta arenas cl
# rikitea pf
# kaka tm
# rikitea pf
# hermanus za
# oranjemund na
# awjilah ly
# samaniego co
# chuy uy
# punta arenas cl
# puerto ayora ec
# faanui pf
# salalah om
# mataura pf
# atuona pf
# mar del plata ar
# mehamn no
# rikitea pf
# betioky mg
# airai pw
# okhotsk ru
# hobart au
# belushya guba ru
# grand river south east mu
# arraial do cabo br
# alghero it
# buxton gb
# medicine hat ca
# tuktoyaktuk ca
# khatanga ru
# taree au
# ponta do sol pt
# gorontalo id
# bathsheba bb
# sinnamary gf
# upernavik gl
# souillac mu
# sitka us
# busselton au
# puerto ayora ec
# zhigalovo ru
# pisco pe
# tamiahua mx
# port alfred za
# norman wells ca
# beyneu kz
# mar del plata ar
# barrow us
# hobart au
# ilulissat gl
# port hedland au
# columbus us
# busselton au
# tiksi ru
# vanimo pg
# dubrajpur in

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 615

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial'

city = 'Boston'

query_url = f'{url}&appid={weather_api_key}'

query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=6dc244aefdc1601dd829f060569da2bc'

# %%
request = requests.get(query_url).json()
request["sys"]["country"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/z0/kjc758js7xv5nmkgb1vfrh3w0000gn/T/ipykernel_85091/3573372283.py in <module>
#       1 request = requests.get(query_url).json()
# ----> 2 request["sys"]["country"]
#
# KeyError: 'sys'

# %%
lat = request["coord"]["lat"]
lng = request["coord"]["lon"]
max_temp = request["main"]["temp_max"]
humidity = request["main"]["humidity"]
clouds = request["clouds"]["all"]
wind = request["wind"]["speed"]

print(lat, lng,max_temp,humidity,clouds,wind)
# Out:
# 42.3584 -71.0598 59.11 95 100 9.22
# 1670463309

# %%
date = request["dt"]

datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-12-08 01:35:09'

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/z0/kjc758js7xv5nmkgb1vfrh3w0000gn/T/ipykernel_85091/2594370469.py in <module>
#       6         set_count += 1
#       7         record_count = 1
# ----> 8         time.sleep(60)
#       9
#      10     # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
city_data =[]

print("Beinning Data Retrieval ")
print("----------------------- ")

#counters
record_count = 1 
set_count = 1

for i, city in enumerate(cities):

    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
        time.sleep(5)

    request_url = query_url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of set {set_count} | {city}")

    record_count += 1

    try:
            # Parse the JSON and retrieve data.
        city_weather = requests.get(request_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beinning Data Retrieval
# -----------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z0/kjc758js7xv5nmkgb1vfrh3w0000gn/T/ipykernel_86495/1552642199.py in <module>
#       8 set_count = 1
#       9
# ---> 10 for i, city in enumerate(cities):
#      11
#      12     if(i % 50 == 0 and i >= 50):
#
# NameError: name 'cities' is not defined

# %%
len(city_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z0/kjc758js7xv5nmkgb1vfrh3w0000gn/T/ipykernel_86495/3303700667.py in <module>
# ----> 1 len(city_data)
#
# NameError: name 'city_data' is not defined
